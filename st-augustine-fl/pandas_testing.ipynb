# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data_agg.csv")
print(df.shape)
print(df.head())
# Out:
# (353, 6)
#                     Timestamp    Object Confidence Score  Frame Read Time  \
# 0  2023-08-22 12:19:33.975860    person            0.782         0.015972
# 1  2023-08-22 12:19:33.975860    person           0.7659         0.015972
# 2  2023-08-22 12:19:33.975860     clock           0.6831         0.015972
# 3  2023-08-22 12:19:33.975860  umbrella           0.4214         0.015972
# 4  2023-08-22 12:19:33.975860  umbrella           0.2784         0.015972
#
#    Inference Time  Postprocess Time
# 0        0.145333           0.00074
# 1        0.145333           0.00074
# 2        0.145333           0.00074
# 3        0.145333           0.00074
# 4        0.145333           0.00074

# %%
df["Object"].value_counts()
# Out:
# Object
# No overlay    138
# person        101
# umbrella       76
# clock          38
# Name: count, dtype: int64

# %%
df["Total"] = df.iloc[:, 3:6].sum(axis=1)
df.head()
# Out:
#                     Timestamp    Object Confidence Score  Frame Read Time  \
# 0  2023-08-22 12:19:33.975860    person            0.782         0.015972
# 1  2023-08-22 12:19:33.975860    person           0.7659         0.015972
# 2  2023-08-22 12:19:33.975860     clock           0.6831         0.015972
# 3  2023-08-22 12:19:33.975860  umbrella           0.4214         0.015972
# 4  2023-08-22 12:19:33.975860  umbrella           0.2784         0.015972
#
#    Inference Time  Postprocess Time     Total
# 0        0.145333           0.00074  0.162045
# 1        0.145333           0.00074  0.162045
# 2        0.145333           0.00074  0.162045
# 3        0.145333           0.00074  0.162045
# 4        0.145333           0.00074  0.162045

# %%
no_inference = df[df["Object"] == "No overlay"]
inference = df[df["Object"] != "No overlay"]

# %%
no_inference_mean = no_inference[["Frame Read Time", "Inference Time", "Postprocess Time", "Total"]].mean(axis=0)
no_inference_mean = round(no_inference_mean*1000, 2)
no_inference_mean
# Out:
# Frame Read Time     3.27
# Inference Time      0.00
# Postprocess Time    0.00
# Total               3.27
# dtype: float64

# %%
inference_mean = inference[["Frame Read Time", "Inference Time", "Postprocess Time", "Total"]].mean(axis=0)
inference_mean = round(inference_mean*1000, 2)
inference_mean
# Out:
# Frame Read Time      15.88
# Inference Time      121.10
# Postprocess Time      1.82
# Total               138.79
# dtype: float64

# %%
test = pd.concat([inference_mean, no_inference_mean], axis=1, ignore_index=True)
test2 = pd.DataFrame(test)
test3 = test2.transpose()
test3["Type"] = ["Inference", "No Inference"]
test3 = test3[["Type", "Frame Read Time", "Inference Time", "Postprocess Time", "Total"]]
test3
# Out:
#            Type  Frame Read Time  Inference Time  Postprocess Time   Total
# 0     Inference            15.88           121.1              1.82  138.79
# 1  No Inference             3.27             0.0              0.00    3.27

# %%
chart_data = pd.DataFrame(
    np.random.randn(20, 3),
    columns=['a', 'b', 'c'])

# %%
preds_df = inference[["Timestamp", "Object", "Confidence Score"]]
preds_df.head()
# Out:
#                     Timestamp    Object Confidence Score
# 0  2023-08-22 12:19:33.975860    person            0.782
# 1  2023-08-22 12:19:33.975860    person           0.7659
# 2  2023-08-22 12:19:33.975860     clock           0.6831
# 3  2023-08-22 12:19:33.975860  umbrella           0.4214
# 4  2023-08-22 12:19:33.975860  umbrella           0.2784

# %%
inference.head()
# Out:
#                     Timestamp    Object Confidence Score  Frame Read Time  \
# 0  2023-08-22 12:19:33.975860    person            0.782         0.015972
# 1  2023-08-22 12:19:33.975860    person           0.7659         0.015972
# 2  2023-08-22 12:19:33.975860     clock           0.6831         0.015972
# 3  2023-08-22 12:19:33.975860  umbrella           0.4214         0.015972
# 4  2023-08-22 12:19:33.975860  umbrella           0.2784         0.015972
#
#    Inference Time  Postprocess Time     Total
# 0        0.145333           0.00074  0.162045
# 1        0.145333           0.00074  0.162045
# 2        0.145333           0.00074  0.162045
# 3        0.145333           0.00074  0.162045
# 4        0.145333           0.00074  0.162045

# %%
counts_df = inference[["Timestamp", "Object", "Confidence Score"]]
counts = counts_df.groupby(["Timestamp", "Object"])["Confidence Score"].count()
counts_df_2.head()
# Out:
#                                      Confidence Score
# Timestamp                  Object
# 2023-08-22 12:19:28.477207 clock                    1
#                            person                   3
#                            umbrella                 2
# 2023-08-22 12:19:28.597531 clock                    1
#                            person                   3

# %%
counts_df_3 = counts_df_2.reset_index()
counts_df_3 = counts_df_3.rename(columns={"Confidence Score": "Counts"})
counts_df_3 = counts_df_3.pivot(columns="Object", values="Counts")
counts_df_3.head()
# Out:
# Object  clock  person  umbrella
# 0         1.0     NaN       NaN
# 1         NaN     3.0       NaN
# 2         NaN     NaN       2.0
# 3         1.0     NaN       NaN
# 4         NaN     3.0       NaN

# %%
df2_df.head()
# Out:
#    Courses Duration  Fee
# 0   Hadoop   35days    2
# 1   Pandas   60days    1
# 2  PySpark   50days    1
# 3   Python   40days    1
# 4   Python   50days    1

# %%
counts_df = inference.pivot(columns="Object", values="Object")
counts_df.head()
# Out:
# Object  clock  person  umbrella
# 0         NaN  person       NaN
# 1         NaN  person       NaN
# 2       clock     NaN       NaN
# 3         NaN     NaN  umbrella
# 4         NaN     NaN  umbrella

# %%
counts_df = inference.pivot_table(index="Timestamp", columns="Object", values = "Object", aggfunc = "count")
counts_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 counts_df = inference.pivot_table(index="Timestamp", columns="Object", values = "Object", aggfunc = "count")
#       2 counts_df.head()
#
# File ~\Documents\tasks\public-modzy-github\streamlit-experimentation\venv\lib\site-packages\pandas\core\frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
#    8580         self,
#    8581         values=values,
#    8582         index=index,
#    8583         columns=columns,
#    8584         aggfunc=aggfunc,
#    8585         fill_value=fill_value,
#    8586         margins=margins,
#    8587         dropna=dropna,
#    8588         margins_name=margins_name,
#    8589         observed=observed,
#    8590         sort=sort,
#    8591     )
#
# File ~\Documents\tasks\public-modzy-github\streamlit-experimentation\venv\lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File ~\Documents\tasks\public-modzy-github\streamlit-experimentation\venv\lib\site-packages\pandas\core\reshape\pivot.py:166, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     163             pass
#     164     values = list(values)
# --> 166 grouped = data.groupby(keys, observed=observed, sort=sort)
#     167 agged = grouped.agg(aggfunc)
#     169 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# File ~\Documents\tasks\public-modzy-github\streamlit-experimentation\venv\lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\Documents\tasks\public-modzy-github\streamlit-experimentation\venv\lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\Documents\tasks\public-modzy-github\streamlit-experimentation\venv\lib\site-packages\pandas\core\groupby\grouper.py:980, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     976     in_axis, name, gpr = True, gpr, obj[gpr]
#     977     if gpr.ndim != 1:
#     978         # non-unique columns; raise here to get the name in the
#     979         # exception message
# --> 980         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     981     exclusions.add(name)
#     982 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'Object' not 1-dimensional

# %%
chart_data
# Out:
#            a         b         c
# 0   0.037554  0.567393 -0.305786
# 1  -0.120027 -1.089274 -1.134160
# 2  -0.120457  0.777886  1.321787
# 3   1.250871 -0.786714 -0.470108
# 4  -0.931649  1.723305 -0.332737
# 5  -1.293890  0.134163  0.554823
# 6   0.064564  0.053150 -0.158523
# 7   0.759735 -0.593186  0.681575
# 8  -2.099314  0.514270  0.383386
# 9   1.276020  1.584311 -1.882038
# 10 -0.577664  1.691556 -0.447283
# 11 -0.515815  0.655083  0.106770
# 12 -1.606575 -0.957769 -0.717164
# 13 -1.361637  0.580226 -0.428381
# 14  0.205447 -0.738106  1.021504
# 15  0.803523 -0.666154 -0.802968
# 16 -1.278580  0.396255 -0.500527
# 17 -1.014296  0.822708 -0.482861
# 18 -2.926107 -1.869533  2.392054
# 19 -0.836382 -0.134512 -0.621690
